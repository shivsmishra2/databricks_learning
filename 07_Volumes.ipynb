# %%
# %sql
create volume dev.bronze.managed_volume
comment 'This is a managed volume';

# %%
# %sql
describe volume dev.bronze.managed_volume;

# %%
# %sh
ls -lrt .

# %%
# %sh
wget https://media.githubusercontent.com/media/subhamkharwal/pyspark-zero-to-hero/refs/heads/master/datasets/emp.csv

# %%
# %sh
pwd

# %%
dbutils.fs.mkdirs("/Volumes/dev/bronze/managed_volume/files")

# %%
dbutils.fs.cp("file:/Workspace/Users/shivshekharmishra@outlook.com/databricks_learning/emp.csv","/Volumes/dev/bronze/managed_volume/files")

# %%
# %sql
select * from csv.`/Volumes/dev/bronze/managed_volume/files/emp.csv`;

# %% [markdown]
# ### creating external volume

# %%
# %sql
create external volume dev.bronze.ext_volume
comment 'this is external volume'
location 'abfss://adb@azstorageadls.dfs.core.windows.net/ext_volume'

# %%
dbutils.fs.mkdirs('/Volumes/dev/bronze/ext_volume/files');

# %%
dbutils.fs.cp("file:/Workspace/Users/shivshekharmishra@outlook.com/databricks_learning/emp.csv","/Volumes/dev/bronze/ext_volume/files")

# %%
# %sql
select * from csv.`abfss://adb@azstorageadls.dfs.core.windows.net/ext_volume/files/emp.csv`;

# %% [markdown]
# ### Dropping Managed & External Volume and checking the underneath data

# %%
# %sql
drop volume dev.bronze.managed_volume;
    
drop volume dev.bronze.ext_volume;
