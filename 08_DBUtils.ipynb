# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
display(dbutils.fs.ls("file:/"))

# %%
display(dbutils.fs.ls("/Volumes/dev/bronze/ext_volume/files"))

# %%
dbutils.fs.head("dbfs:/Volumes/dev/bronze/ext_volume/files/emp.csv")
