# %%
dbutils.widgets.text("cust_id", "500", "Input_Cust_ID")

# %%
 dbutils.widgets.get("cust_id")

# %%
# %sql
select :cust_id

# %% [markdown]
# ### SECRETS

# %%
dbutils.secrets.help()

# %% [markdown]
# ### NOTEBOOK
