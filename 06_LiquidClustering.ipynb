# %%
# %sql
alter table dev.bronze.sales cluster by (Country);

# %%
# %sql
create table dev.bronze.sales_lc as Select * from 
read_files('dbfs:/databricks-datasets/online_retail/data-001/data.csv',
header=>true,
format=> 'csv'
)
