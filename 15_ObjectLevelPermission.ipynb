# %%
# %sql SHOW GRANTS ON METASTORE

# %%
# %sql
GRANT CREATE CATALOG ON METASTORE TO `DA_Group`

# %%
# %sql SHOW GRANTS ON METASTORE
