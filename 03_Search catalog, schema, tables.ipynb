# %% [markdown]
# ### SEARCH CATALOG | SCHEMAS | TABLES

# %%
# %sql
show catalogs like 'dev*'

# %%
# %sql
show schemas in dev like 'bronze*'

# %%
# %sql
show tables in dev.bronze like 'raw*'

# %% [markdown]
# ### SEARCH FOR TABLES USING PYTHON

# %%
# %scala
spark.catalog.tableExists("dev.bronze.raw_sale")

# %%
# %sql
describe history dev.bronze.raw_sale;

# %%
# %sql

select * from dev.bronze.raw_sale@v0;

# %%
# %sql
select * from dev.bronze.raw_sale@v1;
