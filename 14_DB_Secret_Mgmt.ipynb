# %%
# AKV backed secret scope

dbutils.secrets.help()

# %%
# provides all the scopes created
dbutils.secrets.listScopes()

# %%
# Specific scopr to check all secrets: if nothing stores it displays "[]"
dbutils.secrets.list("akv")

# %%
# Fetch password from Key vault
dbutils.secrets.get(scope = "akv", key = "db-password")

# %%
# check all the scopes databricks & azure
dbutils.secrets.listScopes()

# %%
dbutils.secrets.list("db-scope")

# %%
dbutils.secrets.get("db-scope","db-host")
