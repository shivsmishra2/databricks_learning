# %% [markdown]
# ### Header

# %%
# %sql
show databases;

# %%
# %sh
ls -lrt

# %%
# %scala
spark.range(0,10).show()

# %% [markdown]
# new header

# %%
# %scala
var str = "this is my bed and bedside table besides"
var wordcnt = str.split("\\s+").length
println(s"Total words : $wordcnt")
println("Total words in the string :"+str+" :: " +wordcnt)
//println(s"Total words: $wordcnt")
