# %%
# Run the child notebook with parameter - sales 
dbutils.notebook.run("10_Notebook orchestration", 600, {"dept_id": "OFFICE"})
# Another filter can be sales
# Middle parameter is timeout in seconds
# can pass multi params to child notebook {"dept_id": "sales","dept_id2": "engineering","cust_id": "C001"}
