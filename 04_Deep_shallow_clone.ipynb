# %% [markdown]
# ### DEEP CLONE

# %%
# %sql
create table dev.bronze.raw_sale_dc DEEP clone dev.bronze.raw_sale;

# %% [markdown]
# ### shallow clone

# %%
# %sql
create table dev.bronze.raw_sale_sc shallow clone dev.bronze.raw_sale;

# %%
# %sql
select * from dev.bronze.raw_sale_dc;

# %%
# %sql
select * from dev.bronze.raw_sale_sc;

# %%
# %sql describe extended dev.bronze.raw_sale

# %%
# %sql describe dev.bronze.raw_sale

# %%
# %sql describe formatted dev.bronze.raw_sale;

# %%
# %sql describe history dev.bronze.raw_sale_dc;
